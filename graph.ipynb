# %% [markdown]
# # Word frequency list
# Here we are reading and analyzing the word frequency list. The rank is the position in the list, the frequency is the number of times the word appears in the corpus, and the word is the word itself.

# %%
# Import panda, numpy, matplotlib, and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Read in the data
df = pd.read_csv('word-freq.txt', sep='\t', header=None)
df.columns = ['word', 'freq']
# Create the column for the rank
df['rank'] = df.index + 1

# %% [markdown]
# ## Plotting the word frequency list
# ### Checklist:
# - X axis: rank. Make sure to make it logarithmic.
# - Y axis: frequency. Make sure to make it logarithmic.
# - Make sure to label the axes and give the plot a title.
# - Make sure to show the plot.

# %%
# Plot the data. Make sure to use a log scale for the y-axis and x axis
plt.loglog(df['rank'], df['freq'])
plt.xlabel('Rank')
plt.ylabel('Frequency')
plt.title('Zipf\'s Law')
plt.show()
plt.savefig('wordfreq.png')

# Create a linear regression model for the data and show the summary
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(np.log(df['rank']), np.log(df['freq']))
print('slope: ', slope)
print('intercept: ', intercept)
print('r_value: ', r_value)
print('p_value: ', p_value)
print('std_err: ', std_err)

# Plot the regression line on top of the data and show the equation for the line in the graph together with the R^2 value. Make sure to use dotted lines for the regression line
plt.loglog(df['rank'], df['freq'])
plt.xlabel('Rank')
plt.ylabel('Frequency')
plt.title('Zipf\'s Law')
plt.plot(df['rank'], np.exp(intercept)*df['rank']**slope, 'r--')
plt.text(0.1, 0.1, 'y = ' + str(np.exp(intercept)) + 'x^' + str(slope) + '\nR^2 = ' + str(r_value**2))
plt.show()
plt.savefig('graph.png')
# Out:
# slope:  -1.5642624870960948
# intercept:  29.686398236393902
# r_value:  -0.990755162246467
# p_value:  0.0
# std_err:  0.0006857396883689712
